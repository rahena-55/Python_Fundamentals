# %%
print("Hello all welcome to python programming !!")
# Out:
# Hello all welcome to python programming !!

# %%
print(Hello World)
# Out:
#   Cell In[2], line 1
#     print(Hello World)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("hello world")
# Out:
# hello world
