# %%
firstname = "bantumilli"

# %%
lastname = "rahena"

# %%
fullname = f" {firstname} {lastname} "

# %%
print(fullname)
# Out:
#  bantumilli rahena

# %% [raw]
# print(fullname.title())

# %%
fullname = f"{firstname} {lastname}"
print(fullname.title())

message = f"keep up the good work , {fullname.title()}"
print(message)
print("Fav_prog:python,java,c,c++,swift")
print("Fav_prog\npython\njava\nc\nc++\nswift")
print("Fav_prog\n\tpython\n\tjava\n\tc\n\tc++\n\tswift")
# Out:
# Bantumilli Rahena
# keep up the good work , Bantumilli Rahena
# Fav_prog:python,java,c,c++,swift
# Fav_prog
# python
# java
# c
# c++
# swift
# Fav_prog
# 	python
# 	java
# 	c
# 	c++
# 	swift

# %%
name = 'python'
name2 = ' python'
name3 = 'python '
print(name)
print(name2)
print(name3)
name.lstrip()
# Out:
# python
#  python
# python
# 'python'

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# 'python'

# %%
name.rstrip()
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# ' python'

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# 'python'

# %%
name3.lstrip()
# Out:
# 'python '
